# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('Data.xlsx')
df.describe()
# Out:
#          Year        Dues        Income     Filing     Insurance    Landscape  \
# count     3.0    3.000000      3.000000    3.000000     3.000000     3.000000
# mean   2023.0  266.666667  16122.000000  310.000000  1060.453333  8533.320000
# std       1.0   38.188131   1878.208721   40.926764   144.202892   126.993965
# min    2022.0  225.000000  13954.000000  265.000000   894.000000  8460.000000
# 25%    2022.5  250.000000  15555.000000  292.500000  1016.940000  8460.000000
# 50%    2023.0  275.000000  17156.000000  320.000000  1139.880000  8460.000000
# 75%    2023.5  287.500000  17206.000000  332.500000  1143.680000  8569.980000
# max    2024.0  300.000000  17256.000000  345.000000  1147.480000  8679.960000
#
#            Legal  Management      Member      Other     Postage      Expenses  \
# count   3.000000         3.0    3.000000   3.000000    3.000000      3.000000
# mean    8.000000      4800.0  200.000000  20.000000  483.333333  15415.106667
# std    13.856406         0.0  264.575131  34.641016  189.296945    327.450189
# min     0.000000      4800.0    0.000000   0.000000  350.000000  15038.960000
# 25%     0.000000      4800.0   50.000000   0.000000  375.000000  15304.420000
# 50%     0.000000      4800.0  100.000000   0.000000  400.000000  15569.880000
# 75%    12.000000      4800.0  300.000000  30.000000  550.000000  15603.180000
# max    24.000000      4800.0  500.000000  60.000000  700.000000  15636.480000
#
#                Net  Inflation  Dollar Value
# count     3.000000   3.000000      3.000000
# mean    706.893333   0.050033      1.036667
# std    1554.024667   0.026671      0.035119
# min   -1084.960000   0.028900      1.000000
# 25%     217.280000   0.035050      1.020000
# 50%    1519.520000   0.041200      1.040000
# 75%    1602.820000   0.060600      1.055000
# max    1686.120000   0.080000      1.070000

# %%
df.plot(x='Year')
plt.show()

# %%
plt.figure(figsize=(12,6)) 

plt.plot(df['Year'],df['Filing '], label='Filing')
plt.plot(df['Year'],df['Insurance'], label='Insurance')
plt.plot(df['Year'],df['Landscape'], label='Landscape')
plt.plot(df['Year'],df['Legal'], label='Legal')
plt.plot(df['Year'],df['Management'], label='Management')
plt.plot(df['Year'],df['Member'], label='Member')
plt.plot(df['Year'],df['Other'], label='Other')
plt.plot(df['Year'],df['Postage'], label='Postage')

plt.xticks([2022,2023,2024])
plt.xlabel('Year')
plt.ylabel('Cost ($)')
plt.title('Income [ $13,954, $17,256, $17,156 ] //// Expenses [ $15,038, $15,569, $15,636]')
plt.legend()

plt.figure(figsize=(12,6)) 

plt.subplot(1,2,1)

plt.bar(df['Year'],df['Dues'], label='Dues', edgecolor='red', linewidth=2, color='red')
plt.xticks([2022,2023,2024])
plt.xlabel('Year')
plt.ylabel('Cost ($)')
plt.title('Dues')
plt.legend()

plt.subplot(1,2,2)

plt.bar(df['Year'],df['Net'], label='Net', edgecolor='blue', linewidth=2, color='blue')
plt.xticks([2022,2023,2024])
plt.xlabel('Year')
plt.ylabel('Cost ($)')
plt.title('Net')
plt.legend()

plt.show()

# %%
df = pd.read_excel('Data2.xlsx')
df
# Out:
#    Year  Dues  Homes    Exp  Income  Filing   Insurance  Landscape  Legal  \
# 0  2022   225     62  13950   13954      265     894.00    8679.96      0
# 1  2023   275     62  17050   17256      320    1139.88    8460.00      0
# 2  2024   300     62  18600   17156      345    1147.48    8460.00     24
# 3  2025   300     62  18600   17256      345    1147.48    8460.00     24
# 4  2026   260     62  16120   17050      345    1147.48    8460.00     24
#
#    Management  Member  Other  Postage  Expenses      Net  Inflation  \
# 0        4800       0      0      400  15038.96 -1084.96     0.0800
# 1        4800     500      0      350  15569.88  1686.12     0.0412
# 2        4800     100     60      700  15636.48  1519.52     0.0289
# 3        4800     100     60      700  15636.48  1519.52     0.0289
# 4        4800     100     60      700  15636.48   483.52     0.0289
#
#    Dollar Value
# 0          1.00
# 1          1.04
# 2          1.07
# 3          1.07
# 4          1.07

# %%
df.describe()
# Out:
#               Year        Dues  Homes           Exp        Income    Filing   \
# count     5.000000    5.000000    5.0      5.000000      5.000000    5.00000
# mean   2024.000000  272.000000   62.0  16864.000000  16534.400000  324.00000
# std       1.581139   31.344856    0.0   1943.381074   1445.000623   34.71311
# min    2022.000000  225.000000   62.0  13950.000000  13954.000000  265.00000
# 25%    2023.000000  260.000000   62.0  16120.000000  17050.000000  320.00000
# 50%    2024.000000  275.000000   62.0  17050.000000  17156.000000  345.00000
# 75%    2025.000000  300.000000   62.0  18600.000000  17256.000000  345.00000
# max    2026.000000  300.000000   62.0  18600.000000  17256.000000  345.00000
#
#          Insurance    Landscape      Legal  Management      Member      Other  \
# count     5.000000     5.000000   5.000000         5.0    5.000000   5.000000
# mean   1095.264000  8503.992000  14.400000      4800.0  160.000000  36.000000
# std     112.558115    98.369102  13.145341         0.0  194.935887  32.863353
# min     894.000000  8460.000000   0.000000      4800.0    0.000000   0.000000
# 25%    1139.880000  8460.000000   0.000000      4800.0  100.000000   0.000000
# 50%    1147.480000  8460.000000  24.000000      4800.0  100.000000  60.000000
# 75%    1147.480000  8460.000000  24.000000      4800.0  100.000000  60.000000
# max    1147.480000  8679.960000  24.000000      4800.0  500.000000  60.000000
#
#           Postage      Expenses          Net  Inflation  Dollar Value
# count    5.000000      5.000000     5.000000   5.000000      5.000000
# mean   570.000000  15503.656000   824.744000   0.041580      1.050000
# std    178.885438    261.368818  1169.486979   0.022128      0.030822
# min    350.000000  15038.960000 -1084.960000   0.028900      1.000000
# 25%    400.000000  15569.880000   483.520000   0.028900      1.040000
# 50%    700.000000  15636.480000  1519.520000   0.028900      1.070000
# 75%    700.000000  15636.480000  1519.520000   0.041200      1.070000
# max    700.000000  15636.480000  1686.120000   0.080000      1.070000

# %%
plt.figure(figsize=(12,6)) 

plt.plot(df['Year'],df['Filing '], label='Filing')
plt.plot(df['Year'],df['Insurance'], label='Insurance')
plt.plot(df['Year'],df['Landscape'], label='Landscape')
plt.plot(df['Year'],df['Legal'], label='Legal')
plt.plot(df['Year'],df['Management'], label='Management')
plt.plot(df['Year'],df['Member'], label='Member')
plt.plot(df['Year'],df['Other'], label='Other')
plt.plot(df['Year'],df['Postage'], label='Postage')

plt.xticks([2022,2023,2024, 2025, 2026])
plt.xlabel('Year')
plt.ylabel('Cost ($)')
plt.title('Income [ $13,954, $17,256, $17,156, $17,256, $17,256] //// Expenses [ $15,038, $15,569, $15,636, $15,636, $15,636]')
plt.legend()

plt.figure(figsize=(12,6)) 

plt.subplot(1,2,1)

plt.bar(df['Year'],df['Dues'], label='Dues', edgecolor='red', linewidth=2, color='red')
plt.xticks([2022,2023,2024, 2025, 2026])
plt.xlabel('Year')
plt.ylabel('Cost ($)')
plt.title('Dues')
plt.legend()

plt.subplot(1,2,2)

plt.bar(df['Year'],df['Net'], label='Net', edgecolor='blue', linewidth=2, color='blue')
plt.xticks([2022,2023,2024, 2025, 2026])
plt.xlabel('Year')
plt.ylabel('Cost ($)')
plt.title('Net')
plt.legend()

plt.show()
